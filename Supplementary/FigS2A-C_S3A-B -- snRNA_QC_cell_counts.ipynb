# %%
import scanpy as sc
import anndata as ad
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
adata = sc.read_h5ad('data/snRNA_data/all_celltype.h5ad')

# %%
with plt.rc_context({"figure.figsize": (15, 3)}):
    ax = sc.pl.violin(adata, 'n_genes_by_counts', groupby='sample', palette="Set3",
                      stripplot=False, rotation=45, show=False)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    plt.show()
# Out:
# /home/xzh/Software/anaconda3/envs/scvi/lib/python3.12/site-packages/scanpy/plotting/_anndata.py:928: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# /tmp/ipykernel_2842420/405628135.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
with plt.rc_context({"figure.figsize": (15, 3)}):
    ax = sc.pl.violin(adata, 'total_counts', groupby='sample', palette="Set3",
                      stripplot=False, rotation=45, show=False)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    plt.show()
# Out:
# /home/xzh/Software/anaconda3/envs/scvi/lib/python3.12/site-packages/scanpy/plotting/_anndata.py:928: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# /tmp/ipykernel_2842420/3583189369.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
with plt.rc_context({"figure.figsize": (15, 3)}):
    ax = sc.pl.violin(adata, 'pct_counts_mt', groupby='sample', palette="Set3",
                      stripplot=False, rotation=45, show=False)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    plt.show()
# Out:
# /home/xzh/Software/anaconda3/envs/scvi/lib/python3.12/site-packages/scanpy/plotting/_anndata.py:928: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(
# /tmp/ipykernel_2842420/3775797851.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
counts = adata.obs['condition'].value_counts().reset_index()
counts.columns = ['condition', 'cell_count']
counts['log10_count'] = np.log10(counts['cell_count'])
counts['condition'] = pd.Categorical(counts['condition'], categories=['Contralateral','COH_2w','COH_4w','COH_8w'], ordered=True)

with plt.rc_context({"figure.figsize": (3, 4)}):
    sns.set_style("ticks")
    ax = sns.barplot(
        data=counts, 
        x='condition', 
        y='log10_count', 
        palette="Set2"
    )
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    plt.ylabel('log10(Cell Count)')
    plt.xlabel('Condition')
    plt.show()
# Out:
# /tmp/ipykernel_2842420/335465633.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# /tmp/ipykernel_2842420/335465633.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
counts = adata.obs['mouse'].value_counts().reset_index()
counts.columns = ['mouse', 'cell_count']
counts['log10_count'] = np.log10(counts['cell_count'])

with plt.rc_context({"figure.figsize": (6.75, 4)}):
    sns.set_style("ticks")
    ax = sns.barplot(
        data=counts, 
        x='mouse', 
        y='log10_count', 
        palette="Set3"
    )
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    plt.ylabel('log10(Cell Count)')
    plt.xlabel('Mouse')
    plt.show()
# Out:
# /tmp/ipykernel_2842420/1454278665.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# /tmp/ipykernel_2842420/1454278665.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
