# %%
library(ArchR)
addArchRGenome("mm10")
library(BSgenome.Mmusculus.UCSC.mm10)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
# ...

# %%
addArchRThreads(threads = 30)
# Out:
# Setting default number of Parallel threads to 30.

# %%
proj <- loadArchRProject(path = "/media/xzh/ee40b85b-8e1f-491b-8630-999a9811100c/xq/mouse_glaucoma_snRNA-seq_ATAC-seq/archR/ArchRProject")
# Out:
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
# ...

# %%
p <- plotFragmentSizes(ArchRProj = proj)
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotFragmentSizes-1e5419bf6061-Date-2026-08-27_Time-15-45-37.709169.log
# If there is an issue, please report to github with logFile!
#
# ArchR logging successful to : ArchRLogs/ArchR-plotFragmentSizes-1e5419bf6061-Date-2026-08-27_Time-15-45-37.709169.log
#
# Length of unique values greater than palette, interpolating..

# %%
p
# Out:
# plot without title

# %%
p2 <- plotTSSEnrichment(ArchRProj = proj)
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotTSSEnrichment-1e546007c38e-Date-2026-08-27_Time-17-08-36.57194.log
# If there is an issue, please report to github with logFile!
#
# subThreading Disabled since ArchRLocking is TRUE see `addArchRLocking`
#
# 2026-08-27 17:08:36.910436 : Retinal_GF9 Computing TSS (1 of 54)!, 0.006 mins elapsed.
#
# 2026-08-27 17:12:29.650162 : Retinal_GF9 Finished Computing TSS (1 of 54)!, 3.885 mins elapsed.
#
# 2026-08-27 17:12:29.673142 : Retinal_GF10 Computing TSS (2 of 54)!, 3.885 mins elapsed.
#
# 2026-08-27 17:16:33.780987 : Retinal_GF10 Finished Computing TSS (2 of 54)!, 7.953 mins elapsed.
#
# 2026-08-27 17:16:33.782472 : Retinal_GF10_1 Computing TSS (3 of 54)!, 7.954 mins elapsed.
#
# 2026-08-27 17:20:27.370173 : Retinal_GF10_1 Finished Computing TSS (3 of 54)!, 11.847 mins elapsed.
#
# 2026-08-27 17:20:27.371685 : Retinal_GF11 Computing TSS (4 of 54)!, 11.847 mins elapsed.
#
# ...

# %%
p2
# Out:
# plot without title
