# %%
import scanpy as sc
import anndata as ad
import matplotlib.pyplot as plt

# %%
adata = sc.read_h5ad('data/snRNA_data/RGC.h5ad')

# %%
adata.X = adata.layers['counts'].copy()
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
with plt.rc_context({"figure.figsize": (4, 2)}):
    sc.pl.dotplot(adata,['Piezo1','Trpv4'], groupby='condition', categories_order=['Contralateral','COH_2w','COH_4w','COH_8w'], swap_axes=True, linewidth=0)
